# %%
# NUMBER OF RUNS FOR EACH OPTUNA ITERATION:
# - the number of optuna trials is computed as 1500 // n_runs
n_runs = 30

# AGGREGATION METHOD:
# - 'aggregate': aggregates the MultiSim object on the mean values and computes a single loss
# - 'average': computes the loss of each simulation in the MultiSim and the averages the n_runs losses
method = 'average'

# %%
# %%capture
import sys

if 'google.colab' in sys.modules:
    # !pip install covasim==2.0.3 optuna
    # !git clone https://github.com/mazzio97/EpidemicModelLearning.git
    sys.path.append('EpidemicModelLearning/')

# %%
import optuna as op
import covasim as cv
import seaborn as sns
import matplotlib.pyplot as plt
from src import data, calibration, interventions

sns.set_context('notebook')
sns.set_style('whitegrid')

# NUMBER OF TOTAL SIMULATIONS
n_simulations = 1500

# NUMBER OF OPTUNA TRIALS
n_trials = n_simulations // n_runs
# Out:
# Covasim 2.0.3 (2021-03-11) — © 2021 by IDM

# %%
pop_size = 400e3
pop_scale = 10
cols = ['n_severe', 'n_critical', 'cum_diagnoses', 'cum_deaths']
df = data.get_regional_data(scaling_factor=4.46e6/pop_size)

default_params = dict(
    pop_type='hybrid',
    location='italy',
    start_day=df['date'].iloc[0],
    end_day=df['date'].iloc[-1],
    pop_size=pop_size / pop_scale,
    pop_scale=pop_scale,
    rescale=True,
    n_beds_hosp=pop_size * 370.4 / 100e3,
    n_beds_icu=pop_size * 14.46 / 100e3,
    quar_period=14,
    verbose=0
)

_, axes = plt.subplots(2, 2, figsize=(14, 8), sharex='all')
sns.lineplot(data=df, x='date', y='new_tests', ax=axes[0, 0]).set(title='New Tests', ylabel='')
sns.lineplot(data=df, x='date', y='cum_diagnoses', ax=axes[0, 1]).set(title='Cumulative Cases', ylabel='')
sns.lineplot(data=df, x='date', y='cum_deaths', ax=axes[1, 0]).set(title='Cumulative Deaths', ylabel='')
sns.lineplot(data=df, x='date', y='n_critical', label='critical', color='#1f77b4', linestyle='--', ax=axes[1, 1])
sns.lineplot(data=df, x='date', y='n_severe', label='severe', ax=axes[1, 1]).set(title='Active Cases', ylabel='')
plt.tight_layout()

# %%
def get_calibration_params(trial):
    return dict(
        pop_infected=trial.suggest_int('pop_infected', pop_size // 1e4, pop_size // 1e2, step=5),
        **default_params
    ), dict(
        trace_prob=trial.suggest_float('trace_prob', 0.3, 0.9, step=1e-2),
        trace_time=trial.suggest_float('trace_time', 1.0, 5.0, step=1e-1),
        work_contacts=trial.suggest_float('work_contacts', 0.4, 0.9, step=1e-2),
        school_contacts=trial.suggest_float('school_contacts', 0.2, 0.8, step=1e-2),
        yellow_casual_contacts=trial.suggest_float('yellow_casual_contacts', 0.6, 1.0, step=1e-2),
        orange_casual_contacts=trial.suggest_float('orange_casual_contacts', 0.2, 0.8, step=1e-2),
        init_imports=trial.suggest_float('init_imports', 5.0, 15.0, step=1e-1),
        yellow_imports=trial.suggest_float('yellow_imports', 4.0, 12.0, step=1e-1),
        orange_imports=trial.suggest_float('orange_imports', 2.0, 8.0, step=1e-1),
        init_beta=trial.suggest_float('init_beta', 0.01, 0.02, step=None),
        summer_beta=trial.suggest_float('summer_beta', 0.002, 0.01, step=None),
        winter_beta=trial.suggest_float('winter_beta', 0.01, 0.02, step=None),
        init_symp=trial.suggest_float('init_symp', 0.5, 2.5, log=True),
        init_sev=trial.suggest_float('init_sev', 0.5, 2.0, log=True),
        init_crit=trial.suggest_float('init_crit', 0.5, 2.0, log=True),
        init_death=trial.suggest_float('init_death', 1.5, 4.5, log=True)
    )

# %%
constraint_orderings = [
    ('yellow_casual_contacts', 'orange_casual_contacts'),
    ('init_imports', 'yellow_imports', 'orange_imports'),
    ('init_beta', 'summer_beta'),
    ('winter_beta', 'summer_beta')
]

def objective(trial):
    # define learnable parameters
    initial_params, intervention_params = get_calibration_params(trial)
    # define and run simulations, then return loss
    intervs = interventions.get_calibration_interventions(intervention_params)
    sim = cv.Sim(pars=initial_params, interventions=intervs, datafile=df)
    msim = cv.MultiSim(sim)
    msim.run(n_runs=n_runs)
    violation = calibration.compute_violation(intervention_params, constraint_orderings)
    if method == 'aggregate':
        msim.mean()
        return violation * msim.base_sim.compute_fit(keys=cols, weights={k: 1 for k in cols}).mismatch
    if method == 'average':
        mismatches = [s.compute_fit(keys=cols, weights={k: 1 for k in cols}).mismatch for s in msim.sims]
        return violation * sum(mismatches) / n_runs
    else:
        raise ValueError("method should be either 'aggregate' or 'average'")

study = op.create_study()
study.optimize(func=objective, n_trials=n_trials)
# Out:
# [I 2021-04-16 09:32:04,950] A new study created in memory with name: no-name-f6fba32f-7949-4a21-9207-ec720cc06a03
# [I 2021-04-16 09:36:33,772] Trial 0 finished with value: 1209.4412770390707 and parameters: {'pop_infected': 1250, 'trace_prob': 0.69, 'trace_time': 2.5, 'work_contacts': 0.62, 'school_contacts': 0.34, 'yellow_casual_contacts': 0.77, 'orange_casual_contacts': 0.34, 'init_imports': 11.5, 'yellow_imports': 6.800000000000001, 'orange_imports': 2.2, 'init_beta': 0.016973113085705552, 'summer_beta': 0.008833121144508111, 'winter_beta': 0.014935412300457893, 'init_symp': 0.7523471772377844, 'init_sev': 0.7756352421445826, 'init_crit': 1.691043598946094, 'init_death': 3.6647843189040943}. Best is trial 0 with value: 1209.4412770390707.
# [I 2021-04-16 09:41:04,379] Trial 1 finished with value: 636.9090247141437 and parameters: {'pop_infected': 2495, 'trace_prob': 0.69, 'trace_time': 1.6, 'work_contacts': 0.72, 'school_contacts': 0.8, 'yellow_casual_contacts': 0.63, 'orange_casual_contacts': 0.77, 'init_imports': 10.600000000000001, 'yellow_imports': 7.7, 'orange_imports': 5.5, 'init_beta': 0.010982608269489663, 'summer_beta': 0.004350810771037142, 'winter_beta': 0.011683039190332527, 'init_symp': 0.7003223753912247, 'init_sev': 0.6391757414104323, 'init_crit': 1.4888702024414742, 'init_death': 1.6273911700056438}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 09:45:35,964] Trial 2 finished with value: 1694.9995343091025 and parameters: {'pop_infected': 1510, 'trace_prob': 0.52, 'trace_time': 3.2, 'work_contacts': 0.81, 'school_contacts': 0.34, 'yellow_casual_contacts': 0.85, 'orange_casual_contacts': 0.2, 'init_imports': 5.4, 'yellow_imports': 9.0, 'orange_imports': 7.1000000000000005, 'init_beta': 0.01894041394132873, 'summer_beta': 0.0066123292855516085, 'winter_beta': 0.017409949718561947, 'init_symp': 1.2342825125476578, 'init_sev': 0.909716669665081, 'init_crit': 0.5158283378754238, 'init_death': 4.482632754778145}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 09:50:04,894] Trial 3 finished with value: 2103.581731690647 and parameters: {'pop_infected': 1330, 'trace_prob': 0.39, 'trace_time': 2.4000000000000004, 'work_contacts': 0.8500000000000001, 'school_contacts': 0.44, 'yellow_casual_contacts': 0.95, 'orange_casual_contacts': 0.4, 'init_imports': 8.1, 'yellow_imports': 5.0, 'orange_imports': 3.1, 'init_beta': 0.01282166578288165, 'summer_beta': 0.008334069150877465, 'winter_beta': 0.010663037477741357, 'init_symp': 1.8868261628680802, 'init_sev': 1.638980860234588, 'init_crit': 1.1174422773814994, 'init_death': 4.168131561316795}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 09:54:39,186] Trial 4 finished with value: 2479.9898266336113 and parameters: {'pop_infected': 1500, 'trace_prob': 0.4, 'trace_time': 4.1, 'work_contacts': 0.9, 'school_contacts': 0.49, 'yellow_casual_contacts': 0.64, 'orange_casual_contacts': 0.26, 'init_imports': 7.4, 'yellow_imports': 8.7, 'orange_imports': 6.6000000000000005, 'init_beta': 0.013648445865819906, 'summer_beta': 0.00568276703191728, 'winter_beta': 0.01767273662122478, 'init_symp': 1.062018278768792, 'init_sev': 1.5238907163747586, 'init_crit': 1.1147155981345105, 'init_death': 2.953038953084942}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 09:59:14,482] Trial 5 finished with value: 856.2340594148843 and parameters: {'pop_infected': 1525, 'trace_prob': 0.75, 'trace_time': 2.9000000000000004, 'work_contacts': 0.52, 'school_contacts': 0.27, 'yellow_casual_contacts': 0.99, 'orange_casual_contacts': 0.47000000000000003, 'init_imports': 14.9, 'yellow_imports': 5.0, 'orange_imports': 5.6, 'init_beta': 0.011696297278507102, 'summer_beta': 0.0030846486293311, 'winter_beta': 0.01838352378114743, 'init_symp': 1.6352646397504516, 'init_sev': 0.5253871938997939, 'init_crit': 0.6949174576251214, 'init_death': 2.1675994674781967}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 10:03:53,653] Trial 6 finished with value: 3362.2725780533497 and parameters: {'pop_infected': 1735, 'trace_prob': 0.59, 'trace_time': 2.5, 'work_contacts': 0.46, 'school_contacts': 0.67, 'yellow_casual_contacts': 0.76, 'orange_casual_contacts': 0.78, 'init_imports': 13.1, 'yellow_imports': 6.7, 'orange_imports': 3.7, 'init_beta': 0.014779715166451993, 'summer_beta': 0.007847802397476174, 'winter_beta': 0.016966313186654387, 'init_symp': 1.1340749446116123, 'init_sev': 1.5624011812612324, 'init_crit': 1.2051634569430163, 'init_death': 1.599792807811321}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 10:08:32,749] Trial 7 finished with value: 2573.8884520573943 and parameters: {'pop_infected': 1100, 'trace_prob': 0.75, 'trace_time': 2.9000000000000004, 'work_contacts': 0.48000000000000004, 'school_contacts': 0.39, 'yellow_casual_contacts': 0.9199999999999999, 'orange_casual_contacts': 0.69, 'init_imports': 9.0, 'yellow_imports': 10.5, 'orange_imports': 5.1, 'init_beta': 0.01080228711826715, 'summer_beta': 0.006959355827981335, 'winter_beta': 0.019110762703666753, 'init_symp': 0.7466148846380091, 'init_sev': 1.9932503106958999, 'init_crit': 0.5270804975118487, 'init_death': 1.8654554817120037}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 10:13:14,411] Trial 8 finished with value: 1719.9634312425783 and parameters: {'pop_infected': 1795, 'trace_prob': 0.79, 'trace_time': 2.3, 'work_contacts': 0.8300000000000001, 'school_contacts': 0.5800000000000001, 'yellow_casual_contacts': 0.8, 'orange_casual_contacts': 0.44, 'init_imports': 12.600000000000001, 'yellow_imports': 11.5, 'orange_imports': 7.6000000000000005, 'init_beta': 0.012010322243167868, 'summer_beta': 0.009218335294282395, 'winter_beta': 0.011129761030219324, 'init_symp': 0.5690827348917088, 'init_sev': 1.8276846232478787, 'init_crit': 1.1085069618879522, 'init_death': 3.0792670326181693}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 10:17:46,221] Trial 9 finished with value: 1156.440302047551 and parameters: {'pop_infected': 2465, 'trace_prob': 0.62, 'trace_time': 4.4, 'work_contacts': 0.64, 'school_contacts': 0.64, 'yellow_casual_contacts': 0.6, 'orange_casual_contacts': 0.41000000000000003, 'init_imports': 5.4, 'yellow_imports': 9.600000000000001, 'orange_imports': 3.1, 'init_beta': 0.013986816535919388, 'summer_beta': 0.007437808865508045, 'winter_beta': 0.018124931249286432, 'init_symp': 2.019851181518586, 'init_sev': 0.5376114398590351, 'init_crit': 1.2189917918085342, 'init_death': 1.8392552172951957}. Best is trial 1 with value: 636.9090247141437.
# [I 2021-04-16 10:22:17,737] Trial 10 finished with value: 634.7039062866265 and parameters: {'pop_infected': 3925, 'trace_prob': 0.8700000000000001, 'trace_time': 1.3, 'work_contacts': 0.73, 'school_contacts': 0.8, 'yellow_casual_contacts': 0.6699999999999999, 'orange_casual_contacts': 0.6100000000000001, 'init_imports': 10.4, 'yellow_imports': 6.9, 'orange_imports': 6.1000000000000005, 'init_beta': 0.016362168815713493, 'summer_beta': 0.003783847568568812, 'winter_beta': 0.013323716992588407, 'init_symp': 0.5175276105229741, 'init_sev': 0.666980065264963, 'init_crit': 1.984068395856741, 'init_death': 1.5089571301584142}. Best is trial 10 with value: 634.7039062866265.
# [I 2021-04-16 10:26:42,203] Trial 11 finished with value: 631.0005473019436 and parameters: {'pop_infected': 3800, 'trace_prob': 0.8899999999999999, 'trace_time': 1.0, 'work_contacts': 0.73, 'school_contacts': 0.8, 'yellow_casual_contacts': 0.6699999999999999, 'orange_casual_contacts': 0.6799999999999999, 'init_imports': 10.5, 'yellow_imports': 6.9, 'orange_imports': 6.0, 'init_beta': 0.016744029769225257, 'summer_beta': 0.0038755442332137416, 'winter_beta': 0.01322425044345361, 'init_symp': 0.5006322975665718, 'init_sev': 0.6781176801603934, 'init_crit': 1.9290314744375805, 'init_death': 1.5449620861010478}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 10:31:06,136] Trial 12 finished with value: 1098.614529444912 and parameters: {'pop_infected': 3965, 'trace_prob': 0.8799999999999999, 'trace_time': 1.0, 'work_contacts': 0.73, 'school_contacts': 0.78, 'yellow_casual_contacts': 0.6799999999999999, 'orange_casual_contacts': 0.62, 'init_imports': 9.8, 'yellow_imports': 6.300000000000001, 'orange_imports': 6.3, 'init_beta': 0.016649747662492373, 'summer_beta': 0.002394616473413027, 'winter_beta': 0.013245425802306508, 'init_symp': 0.5177328643991704, 'init_sev': 1.1619654679459583, 'init_crit': 1.909291743284342, 'init_death': 1.511998668862172}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 10:35:27,804] Trial 13 finished with value: 668.3511949660734 and parameters: {'pop_infected': 3905, 'trace_prob': 0.8899999999999999, 'trace_time': 1.1, 'work_contacts': 0.73, 'school_contacts': 0.74, 'yellow_casual_contacts': 0.71, 'orange_casual_contacts': 0.5800000000000001, 'init_imports': 11.7, 'yellow_imports': 5.8, 'orange_imports': 4.4, 'init_beta': 0.016735765490615263, 'summer_beta': 0.00421934843711685, 'winter_beta': 0.01341315070823434, 'init_symp': 0.5029985474492833, 'init_sev': 0.6737913501522039, 'init_crit': 1.9776535357269758, 'init_death': 2.122436930879963}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 10:39:54,014] Trial 14 finished with value: 1251.2161281299695 and parameters: {'pop_infected': 3465, 'trace_prob': 0.8999999999999999, 'trace_time': 1.6, 'work_contacts': 0.5700000000000001, 'school_contacts': 0.71, 'yellow_casual_contacts': 0.72, 'orange_casual_contacts': 0.5700000000000001, 'init_imports': 13.9, 'yellow_imports': 7.7, 'orange_imports': 7.9, 'init_beta': 0.01999679790223251, 'summer_beta': 0.004736991046010058, 'winter_beta': 0.012992407437978727, 'init_symp': 0.6257576995015764, 'init_sev': 1.0018640186410233, 'init_crit': 1.4700790502374048, 'init_death': 2.368922951328672}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 10:44:24,671] Trial 15 finished with value: 792.9407175622508 and parameters: {'pop_infected': 255, 'trace_prob': 0.8200000000000001, 'trace_time': 1.5, 'work_contacts': 0.7, 'school_contacts': 0.5700000000000001, 'yellow_casual_contacts': 0.6699999999999999, 'orange_casual_contacts': 0.69, 'init_imports': 10.5, 'yellow_imports': 4.0, 'orange_imports': 6.0, 'init_beta': 0.018177136088461714, 'summer_beta': 0.0030948079164802313, 'winter_beta': 0.014661291462418931, 'init_symp': 0.937621769643508, 'init_sev': 0.6447405798060988, 'init_crit': 0.7641088678051366, 'init_death': 1.830738724680169}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 10:48:58,505] Trial 16 finished with value: 704.6138070377414 and parameters: {'pop_infected': 3245, 'trace_prob': 0.8400000000000001, 'trace_time': 1.0, 'work_contacts': 0.77, 'school_contacts': 0.8, 'yellow_casual_contacts': 0.6, 'orange_casual_contacts': 0.69, 'init_imports': 7.2, 'yellow_imports': 7.4, 'orange_imports': 7.0, 'init_beta': 0.015799846648354984, 'summer_beta': 0.0020503255503048646, 'winter_beta': 0.012197736030857753, 'init_symp': 0.5184419707161096, 'init_sev': 0.7823487504213463, 'init_crit': 1.9944139115576702, 'init_death': 1.5289136936287886}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 10:53:27,485] Trial 17 finished with value: 1038.006198221333 and parameters: {'pop_infected': 3245, 'trace_prob': 0.49, 'trace_time': 1.9, 'work_contacts': 0.88, 'school_contacts': 0.6100000000000001, 'yellow_casual_contacts': 0.85, 'orange_casual_contacts': 0.53, 'init_imports': 9.2, 'yellow_imports': 5.3, 'orange_imports': 4.7, 'init_beta': 0.018104786712731927, 'summer_beta': 0.005532269420229979, 'winter_beta': 0.015998023147942797, 'init_symp': 0.8581577372985533, 'init_sev': 0.5118655437728403, 'init_crit': 1.574065835379605, 'init_death': 2.686520586846969}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 10:58:01,525] Trial 18 finished with value: 1747.9331009911048 and parameters: {'pop_infected': 3655, 'trace_prob': 0.32, 'trace_time': 3.6, 'work_contacts': 0.79, 'school_contacts': 0.74, 'yellow_casual_contacts': 0.72, 'orange_casual_contacts': 0.64, 'init_imports': 11.4, 'yellow_imports': 4.0, 'orange_imports': 6.0, 'init_beta': 0.015439607812860013, 'summer_beta': 0.003397179732650012, 'winter_beta': 0.014250705662575936, 'init_symp': 2.4400006772314393, 'init_sev': 0.778204225676623, 'init_crit': 0.8719446563514683, 'init_death': 1.7493380256037516}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 11:02:27,835] Trial 19 finished with value: 1602.9770102623697 and parameters: {'pop_infected': 2715, 'trace_prob': 0.8999999999999999, 'trace_time': 5.0, 'work_contacts': 0.67, 'school_contacts': 0.21000000000000002, 'yellow_casual_contacts': 0.65, 'orange_casual_contacts': 0.73, 'init_imports': 8.2, 'yellow_imports': 8.7, 'orange_imports': 7.4, 'init_beta': 0.01950961622055258, 'summer_beta': 0.005114866186792793, 'winter_beta': 0.010125867535371256, 'init_symp': 0.6145397527228631, 'init_sev': 1.146765967980763, 'init_crit': 1.7818671708819644, 'init_death': 2.1080547094225093}. Best is trial 11 with value: 631.0005473019436.
# [I 2021-04-16 11:06:54,090] Trial 20 finished with value: 510.2312944413763 and parameters: {'pop_infected': 2955, 'trace_prob': 0.7, 'trace_time': 1.3, 'work_contacts': 0.5900000000000001, 'school_contacts': 0.69, 'yellow_casual_contacts': 0.6, 'orange_casual_contacts': 0.53, 'init_imports': 12.5, 'yellow_imports': 7.1, 'orange_imports': 4.2, 'init_beta': 0.017970810650048286, 'summer_beta': 0.0038022302529575926, 'winter_beta': 0.0161496162187613, 'init_symp': 0.5009747287588773, 'init_sev': 0.5820755534076556, 'init_crit': 1.4372130272149, 'init_death': 1.6581728764339994}. Best is trial 20 with value: 510.2312944413763.
# [I 2021-04-16 11:11:23,251] Trial 21 finished with value: 565.0514132414277 and parameters: {'pop_infected': 2925, 'trace_prob': 0.71, 'trace_time': 1.3, 'work_contacts': 0.4, 'school_contacts': 0.69, 'yellow_casual_contacts': 0.6, 'orange_casual_contacts': 0.53, 'init_imports': 12.5, 'yellow_imports': 7.0, 'orange_imports': 4.2, 'init_beta': 0.017554628134186925, 'summer_beta': 0.003823595216877304, 'winter_beta': 0.016017814812639055, 'init_symp': 0.5019413459273268, 'init_sev': 0.5935819290027666, 'init_crit': 1.309366178594777, 'init_death': 1.509122929779913}. Best is trial 20 with value: 510.2312944413763.
# [I 2021-04-16 11:15:54,590] Trial 22 finished with value: 597.8084826000656 and parameters: {'pop_infected': 2950, 'trace_prob': 0.65, 'trace_time': 2.0, 'work_contacts': 0.43000000000000005, 'school_contacts': 0.6799999999999999, 'yellow_casual_contacts': 0.6, 'orange_casual_contacts': 0.55, 'init_imports': 12.9, 'yellow_imports': 6.0, 'orange_imports': 4.0, 'init_beta': 0.017730279827309358, 'summer_beta': 0.002536424484956968, 'winter_beta': 0.01601889403331143, 'init_symp': 0.6395662318949946, 'init_sev': 0.5631867817871281, 'init_crit': 1.3343428246404836, 'init_death': 1.682623373740716}. Best is trial 20 with value: 510.2312944413763.
# [I 2021-04-16 11:20:22,117] Trial 23 finished with value: 647.4136105390498 and parameters: {'pop_infected': 2805, 'trace_prob': 0.65, 'trace_time': 2.0, 'work_contacts': 0.42000000000000004, 'school_contacts': 0.53, 'yellow_casual_contacts': 0.6, 'orange_casual_contacts': 0.52, 'init_imports': 15.0, 'yellow_imports': 5.9, 'orange_imports': 4.0, 'init_beta': 0.017887733971420582, 'summer_beta': 0.0024746648687194147, 'winter_beta': 0.016182870071026974, 'init_symp': 0.655068853027778, 'init_sev': 0.5629551009025552, 'init_crit': 1.3316559512994826, 'init_death': 1.6807452451732208}. Best is trial 20 with value: 510.2312944413763.
# [I 2021-04-16 11:24:47,922] Trial 24 finished with value: 499.4872819689556 and parameters: {'pop_infected': 2250, 'trace_prob': 0.56, 'trace_time': 1.9, 'work_contacts': 0.41000000000000003, 'school_contacts': 0.6799999999999999, 'yellow_casual_contacts': 0.61, 'orange_casual_contacts': 0.5, 'init_imports': 13.9, 'yellow_imports': 8.100000000000001, 'orange_imports': 3.4000000000000004, 'init_beta': 0.01919372542683734, 'summer_beta': 0.002841916676827254, 'winter_beta': 0.015917798652799436, 'init_symp': 0.5816157040288179, 'init_sev': 0.5874257773769944, 'init_crit': 0.979469973756144, 'init_death': 1.9732686848530008}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 11:29:15,557] Trial 25 finished with value: 716.8759980359368 and parameters: {'pop_infected': 2350, 'trace_prob': 0.54, 'trace_time': 1.4, 'work_contacts': 0.4, 'school_contacts': 0.67, 'yellow_casual_contacts': 0.62, 'orange_casual_contacts': 0.48000000000000004, 'init_imports': 14.1, 'yellow_imports': 8.2, 'orange_imports': 2.0, 'init_beta': 0.01889786078837784, 'summer_beta': 0.00469801272322205, 'winter_beta': 0.019920634187492053, 'init_symp': 0.5705489659142904, 'init_sev': 0.6022843091234127, 'init_crit': 0.8765324358055052, 'init_death': 2.0152489858421436}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 11:33:39,910] Trial 26 finished with value: 535.4734540612111 and parameters: {'pop_infected': 2120, 'trace_prob': 0.5800000000000001, 'trace_time': 1.8, 'work_contacts': 0.54, 'school_contacts': 0.74, 'yellow_casual_contacts': 0.62, 'orange_casual_contacts': 0.36, 'init_imports': 14.3, 'yellow_imports': 9.9, 'orange_imports': 3.1, 'init_beta': 0.019822931323539853, 'summer_beta': 0.003336938629487916, 'winter_beta': 0.01557653506710719, 'init_symp': 0.8337757279060589, 'init_sev': 0.5050489862233436, 'init_crit': 0.9743342454683247, 'init_death': 2.351645734055434}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 11:38:15,359] Trial 27 finished with value: 560.5003911134813 and parameters: {'pop_infected': 2050, 'trace_prob': 0.59, 'trace_time': 1.9, 'work_contacts': 0.5700000000000001, 'school_contacts': 0.74, 'yellow_casual_contacts': 0.7, 'orange_casual_contacts': 0.34, 'init_imports': 14.200000000000001, 'yellow_imports': 12.0, 'orange_imports': 2.7, 'init_beta': 0.01986225436041497, 'summer_beta': 0.0020880487308242374, 'winter_beta': 0.01680320043250525, 'init_symp': 0.8964841540108137, 'init_sev': 0.5021376517068278, 'init_crit': 0.9317326518659526, 'init_death': 2.4942470121878624}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 11:42:44,862] Trial 28 finished with value: 831.3132352465083 and parameters: {'pop_infected': 2125, 'trace_prob': 0.47, 'trace_time': 1.7000000000000002, 'work_contacts': 0.5700000000000001, 'school_contacts': 0.62, 'yellow_casual_contacts': 0.64, 'orange_casual_contacts': 0.33, 'init_imports': 13.5, 'yellow_imports': 10.0, 'orange_imports': 3.5, 'init_beta': 0.01915127843911297, 'summer_beta': 0.00290199341742923, 'winter_beta': 0.015411527504584445, 'init_symp': 1.3714141692557729, 'init_sev': 0.7177913575810232, 'init_crit': 0.7577401603657181, 'init_death': 1.9727917590974537}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 11:47:17,836] Trial 29 finished with value: 881.745825032874 and parameters: {'pop_infected': 2345, 'trace_prob': 0.56, 'trace_time': 2.3, 'work_contacts': 0.52, 'school_contacts': 0.53, 'yellow_casual_contacts': 0.76, 'orange_casual_contacts': 0.28, 'init_imports': 14.700000000000001, 'yellow_imports': 10.9, 'orange_imports': 2.4, 'init_beta': 0.019948027351662217, 'summer_beta': 0.0033030018788118916, 'winter_beta': 0.01516550967206285, 'init_symp': 0.7935339265841804, 'init_sev': 0.8709660061821805, 'init_crit': 1.001419258943017, 'init_death': 2.727111283559045}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 11:51:51,496] Trial 30 finished with value: 524.262636530489 and parameters: {'pop_infected': 865, 'trace_prob': 0.64, 'trace_time': 2.7, 'work_contacts': 0.61, 'school_contacts': 0.76, 'yellow_casual_contacts': 0.79, 'orange_casual_contacts': 0.38, 'init_imports': 11.9, 'yellow_imports': 9.600000000000001, 'orange_imports': 3.2, 'init_beta': 0.01872697889716046, 'summer_beta': 0.005130703715406183, 'winter_beta': 0.014511420280540878, 'init_symp': 0.9807860795549425, 'init_sev': 0.5094085088837095, 'init_crit': 0.632259793516263, 'init_death': 2.266635442549803}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 11:56:30,398] Trial 31 finished with value: 513.6093045110078 and parameters: {'pop_infected': 820, 'trace_prob': 0.64, 'trace_time': 2.7, 'work_contacts': 0.63, 'school_contacts': 0.73, 'yellow_casual_contacts': 0.82, 'orange_casual_contacts': 0.38, 'init_imports': 11.9, 'yellow_imports': 9.5, 'orange_imports': 3.2, 'init_beta': 0.018708862674586515, 'summer_beta': 0.004633760779919532, 'winter_beta': 0.01430481343080595, 'init_symp': 1.0070529235282082, 'init_sev': 0.5959403893769094, 'init_crit': 0.5953511867066336, 'init_death': 2.3759963806551667}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 12:01:07,909] Trial 32 finished with value: 561.4193869042341 and parameters: {'pop_infected': 805, 'trace_prob': 0.6599999999999999, 'trace_time': 3.3000000000000003, 'work_contacts': 0.61, 'school_contacts': 0.77, 'yellow_casual_contacts': 0.83, 'orange_casual_contacts': 0.44, 'init_imports': 11.5, 'yellow_imports': 9.4, 'orange_imports': 3.5, 'init_beta': 0.018646516016853867, 'summer_beta': 0.006155739193401126, 'winter_beta': 0.01443783246421817, 'init_symp': 1.000920300399911, 'init_sev': 0.601880114146256, 'init_crit': 0.6095397282003833, 'init_death': 2.2706484186203206}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 12:05:47,746] Trial 33 finished with value: 587.0076342866765 and parameters: {'pop_infected': 305, 'trace_prob': 0.71, 'trace_time': 2.7, 'work_contacts': 0.61, 'school_contacts': 0.64, 'yellow_casual_contacts': 0.8999999999999999, 'orange_casual_contacts': 0.37, 'init_imports': 11.8, 'yellow_imports': 8.4, 'orange_imports': 2.5, 'init_beta': 0.017347756485474295, 'summer_beta': 0.004957802306290464, 'winter_beta': 0.013947327308201847, 'init_symp': 1.318101710089123, 'init_sev': 0.7333413032506875, 'init_crit': 0.5843174022232658, 'init_death': 2.49107829577044}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 12:10:24,921] Trial 34 finished with value: 624.7874422294836 and parameters: {'pop_infected': 605, 'trace_prob': 0.62, 'trace_time': 2.6, 'work_contacts': 0.67, 'school_contacts': 0.71, 'yellow_casual_contacts': 0.79, 'orange_casual_contacts': 0.30000000000000004, 'init_imports': 11.9, 'yellow_imports': 9.100000000000001, 'orange_imports': 2.9, 'init_beta': 0.018518586496105, 'summer_beta': 0.004343309419721555, 'winter_beta': 0.01674837396920005, 'init_symp': 1.1986256597370057, 'init_sev': 0.5723032624896256, 'init_crit': 0.6101131202044474, 'init_death': 1.9700852918725622}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 12:15:03,933] Trial 35 finished with value: 698.5795454731264 and parameters: {'pop_infected': 825, 'trace_prob': 0.49, 'trace_time': 3.3000000000000003, 'work_contacts': 0.64, 'school_contacts': 0.76, 'yellow_casual_contacts': 0.88, 'orange_casual_contacts': 0.21000000000000002, 'init_imports': 12.2, 'yellow_imports': 10.5, 'orange_imports': 3.5, 'init_beta': 0.01919173726147191, 'summer_beta': 0.005412520937626392, 'winter_beta': 0.015070923240350705, 'init_symp': 1.5220586597508097, 'init_sev': 0.6350449682681737, 'init_crit': 0.6742269771897834, 'init_death': 2.8057206168570517}. Best is trial 24 with value: 499.4872819689556.
# [I 2021-04-16 12:19:39,373] Trial 36 finished with value: 472.7211687951048 and parameters: {'pop_infected': 1230, 'trace_prob': 0.76, 'trace_time': 2.1, 'work_contacts': 0.6000000000000001, 'school_contacts': 0.71, 'yellow_casual_contacts': 0.85, 'orange_casual_contacts': 0.41000000000000003, 'init_imports': 11.100000000000001, 'yellow_imports': 7.7, 'orange_imports': 4.7, 'init_beta': 0.01823472253382846, 'summer_beta': 0.004123197320733989, 'winter_beta': 0.012544158254463606, 'init_symp': 0.977463251228783, 'init_sev': 0.8378245103565841, 'init_crit': 0.5461998937737914, 'init_death': 3.4070390366878165}. Best is trial 36 with value: 472.7211687951048.
# [I 2021-04-16 12:24:14,951] Trial 37 finished with value: 455.7318473275182 and parameters: {'pop_infected': 1095, 'trace_prob': 0.74, 'trace_time': 2.1, 'work_contacts': 0.48000000000000004, 'school_contacts': 0.71, 'yellow_casual_contacts': 0.86, 'orange_casual_contacts': 0.43000000000000005, 'init_imports': 11.100000000000001, 'yellow_imports': 7.800000000000001, 'orange_imports': 5.0, 'init_beta': 0.017218674001262018, 'summer_beta': 0.006021184589040263, 'winter_beta': 0.01234746343699273, 'init_symp': 0.7222604854551504, 'init_sev': 0.846568605572337, 'init_crit': 0.5022901098286063, 'init_death': 3.3884020686911454}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 12:28:46,933] Trial 38 finished with value: 477.7758787524525 and parameters: {'pop_infected': 1340, 'trace_prob': 0.76, 'trace_time': 2.2, 'work_contacts': 0.48000000000000004, 'school_contacts': 0.46, 'yellow_casual_contacts': 0.87, 'orange_casual_contacts': 0.45, 'init_imports': 13.5, 'yellow_imports': 7.7, 'orange_imports': 5.2, 'init_beta': 0.01722358401649695, 'summer_beta': 0.00595315320723664, 'winter_beta': 0.011924198875858476, 'init_symp': 0.7197461093780404, 'init_sev': 0.8627447822138921, 'init_crit': 0.5155264292518875, 'init_death': 3.5257150948530445}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 12:33:19,772] Trial 39 finished with value: 492.4026596233795 and parameters: {'pop_infected': 1235, 'trace_prob': 0.75, 'trace_time': 2.2, 'work_contacts': 0.46, 'school_contacts': 0.43000000000000005, 'yellow_casual_contacts': 0.88, 'orange_casual_contacts': 0.45, 'init_imports': 13.3, 'yellow_imports': 8.0, 'orange_imports': 5.300000000000001, 'init_beta': 0.015870042480065998, 'summer_beta': 0.00618071446864407, 'winter_beta': 0.012057123845354652, 'init_symp': 0.7086556416988637, 'init_sev': 0.869954753544611, 'init_crit': 0.5025372125685961, 'init_death': 3.669555477786485}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 12:37:53,594] Trial 40 finished with value: 515.4358681823713 and parameters: {'pop_infected': 1245, 'trace_prob': 0.77, 'trace_time': 2.4000000000000004, 'work_contacts': 0.48000000000000004, 'school_contacts': 0.41000000000000003, 'yellow_casual_contacts': 0.95, 'orange_casual_contacts': 0.43000000000000005, 'init_imports': 13.3, 'yellow_imports': 7.800000000000001, 'orange_imports': 5.2, 'init_beta': 0.014471070349246738, 'summer_beta': 0.006372801866018969, 'winter_beta': 0.011962993336711365, 'init_symp': 0.7588149992243083, 'init_sev': 0.8745496538823198, 'init_crit': 0.5006217236192544, 'init_death': 3.692548360359282}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 12:42:29,259] Trial 41 finished with value: 489.5310551143371 and parameters: {'pop_infected': 1680, 'trace_prob': 0.75, 'trace_time': 2.2, 'work_contacts': 0.45, 'school_contacts': 0.44, 'yellow_casual_contacts': 0.87, 'orange_casual_contacts': 0.47000000000000003, 'init_imports': 11.2, 'yellow_imports': 8.2, 'orange_imports': 5.5, 'init_beta': 0.015895480280522987, 'summer_beta': 0.006759877130340493, 'winter_beta': 0.011168241217684444, 'init_symp': 0.7055719909957063, 'init_sev': 1.0032011407960586, 'init_crit': 0.5240853451591538, 'init_death': 3.3545658715310895}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 12:47:06,551] Trial 42 finished with value: 478.0291756949234 and parameters: {'pop_infected': 1780, 'trace_prob': 0.74, 'trace_time': 2.2, 'work_contacts': 0.45, 'school_contacts': 0.47000000000000003, 'yellow_casual_contacts': 0.87, 'orange_casual_contacts': 0.47000000000000003, 'init_imports': 11.100000000000001, 'yellow_imports': 7.5, 'orange_imports': 5.5, 'init_beta': 0.01585106482826692, 'summer_beta': 0.006812899397363605, 'winter_beta': 0.011259132859326434, 'init_symp': 0.6885052791127039, 'init_sev': 0.9845935169175904, 'init_crit': 0.5549865500943871, 'init_death': 3.2677641799407993}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 12:51:45,835] Trial 43 finished with value: 484.8082994597278 and parameters: {'pop_infected': 1780, 'trace_prob': 0.8, 'trace_time': 2.2, 'work_contacts': 0.45, 'school_contacts': 0.48000000000000004, 'yellow_casual_contacts': 0.86, 'orange_casual_contacts': 0.41000000000000003, 'init_imports': 11.0, 'yellow_imports': 7.5, 'orange_imports': 4.800000000000001, 'init_beta': 0.016264284374128475, 'summer_beta': 0.006717024599716157, 'winter_beta': 0.011045933619368523, 'init_symp': 0.7021757006834939, 'init_sev': 0.9882352126843948, 'init_crit': 0.55428447986124, 'init_death': 3.298907167497898}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 12:56:22,497] Trial 44 finished with value: 594.8922353053553 and parameters: {'pop_infected': 1490, 'trace_prob': 0.81, 'trace_time': 3.0, 'work_contacts': 0.5, 'school_contacts': 0.35, 'yellow_casual_contacts': 0.9299999999999999, 'orange_casual_contacts': 0.41000000000000003, 'init_imports': 10.9, 'yellow_imports': 7.300000000000001, 'orange_imports': 4.800000000000001, 'init_beta': 0.017304561862209734, 'summer_beta': 0.007297741805996985, 'winter_beta': 0.01051827574213847, 'init_symp': 0.7891547338999977, 'init_sev': 1.1530651810238701, 'init_crit': 0.5561859230274991, 'init_death': 4.315922520766761}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 13:00:55,836] Trial 45 finished with value: 551.8890230192043 and parameters: {'pop_infected': 1665, 'trace_prob': 0.8500000000000001, 'trace_time': 2.1, 'work_contacts': 0.49, 'school_contacts': 0.48000000000000004, 'yellow_casual_contacts': 0.85, 'orange_casual_contacts': 0.41000000000000003, 'init_imports': 9.5, 'yellow_imports': 6.5, 'orange_imports': 4.800000000000001, 'init_beta': 0.015314065226568389, 'summer_beta': 0.00832343577992362, 'winter_beta': 0.01149102345242888, 'init_symp': 0.6928980682030446, 'init_sev': 1.0663967258412255, 'init_crit': 0.5466228311611748, 'init_death': 3.3782431531773756}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 13:05:32,136] Trial 46 finished with value: 699.9503819837593 and parameters: {'pop_infected': 1930, 'trace_prob': 0.79, 'trace_time': 2.4000000000000004, 'work_contacts': 0.44, 'school_contacts': 0.49, 'yellow_casual_contacts': 0.8999999999999999, 'orange_casual_contacts': 0.48000000000000004, 'init_imports': 10.0, 'yellow_imports': 7.5, 'orange_imports': 5.7, 'init_beta': 0.01639106841659936, 'summer_beta': 0.00711714786105509, 'winter_beta': 0.012590574490735735, 'init_symp': 1.1015129852354777, 'init_sev': 0.9317950183674351, 'init_crit': 0.660268228084862, 'init_death': 3.971027954603527}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 13:10:03,217] Trial 47 finished with value: 548.38401494305 and parameters: {'pop_infected': 1495, 'trace_prob': 0.74, 'trace_time': 3.0, 'work_contacts': 0.53, 'school_contacts': 0.37, 'yellow_casual_contacts': 0.83, 'orange_casual_contacts': 0.32, 'init_imports': 10.9, 'yellow_imports': 8.5, 'orange_imports': 4.5, 'init_beta': 0.017091269123007003, 'summer_beta': 0.007862831109630701, 'winter_beta': 0.010753131279940927, 'init_symp': 0.8547720178161229, 'init_sev': 0.8148323500261654, 'init_crit': 0.560476381488634, 'init_death': 3.093575299194309}. Best is trial 37 with value: 455.7318473275182.
# [I 2021-04-16 13:14:35,855] Trial 48 finished with value: 406.321989290095 and parameters: {'pop_infected': 1105, 'trace_prob': 0.6799999999999999, 'trace_time': 1.7000000000000002, 'work_contacts': 0.47000000000000003, 'school_contacts': 0.46, 'yellow_casual_contacts': 0.96, 'orange_casual_contacts': 0.45, 'init_imports': 8.6, 'yellow_imports': 7.7, 'orange_imports': 5.1, 'init_beta': 0.016288934415778968, 'summer_beta': 0.005803380588283718, 'winter_beta': 0.012672896443816868, 'init_symp': 0.6680089815181749, 'init_sev': 0.9493932154312614, 'init_crit': 0.5277838395144294, 'init_death': 3.414295538338473}. Best is trial 48 with value: 406.321989290095.
# [I 2021-04-16 13:19:13,986] Trial 49 finished with value: 517.0224053879607 and parameters: {'pop_infected': 1070, 'trace_prob': 0.69, 'trace_time': 1.7000000000000002, 'work_contacts': 0.5, 'school_contacts': 0.52, 'yellow_casual_contacts': 0.97, 'orange_casual_contacts': 0.46, 'init_imports': 8.4, 'yellow_imports': 9.0, 'orange_imports': 5.7, 'init_beta': 0.014653298466019276, 'summer_beta': 0.00565132386906448, 'winter_beta': 0.012631301590220063, 'init_symp': 0.5917546526284585, 'init_sev': 1.325614153210943, 'init_crit': 0.7276967938691896, 'init_death': 4.037402242230888}. Best is trial 48 with value: 406.321989290095.

# %%
objectives = study.trials_dataframe()['value']
sns.lineplot(x=objectives.index, y=objectives)
plt.show()

# %%
calibration.inspect_study(study, top=10)[1]
# Out:
#                         count          min  ...         std         best
# objective                  10   406.321989  ...   28.929118   406.321989
# pop_infected               10  1095.000000  ...  591.349680  1105.000000
# trace_prob                 10     0.560000  ...    0.066366     0.680000
# trace_time                 10     1.300000  ...    0.299815     1.700000
# work_contacts              10     0.410000  ...    0.061860     0.470000
# school_contacts            10     0.430000  ...    0.125437     0.460000
# yellow_casual_contacts     10     0.600000  ...    0.118888     0.960000
# orange_casual_contacts     10     0.410000  ...    0.037727     0.450000
# init_imports               10     8.600000  ...    1.588186     8.600000
# yellow_imports             10     7.100000  ...    0.323351     7.700000
# orange_imports             10     3.400000  ...    0.649872     5.100000
# init_beta                  10     0.015851  ...    0.001166     0.016289
# summer_beta                10     0.002842  ...    0.001401     0.005803
# winter_beta                10     0.011046  ...    0.001843     0.012673
# init_symp                  10     0.500975  ...    0.121427     0.668009
# init_sev                   10     0.582076  ...    0.153481     0.949393
# init_crit                  10     0.502290  ...    0.306879     0.527784
# init_death                 10     1.658173  ...    0.688201     3.414296
#
# [18 rows x 7 columns]

# %%
initial_params = {'pop_infected': study.best_params['pop_infected'], **default_params}
intervs = interventions.get_calibration_interventions(study.best_params)
sim = cv.Sim(pars=initial_params, interventions=intervs, datafile=df)
msim = cv.MultiSim(sim)
msim.run(n_runs=30)
msim.mean()
msim.plot(
    list(cols) + ['n_infectious', 'n_susceptible'],
    fig_args={'figsize': (18, 8)},
    scatter_args={'s': 5},
    plot_args={'lw': 2},
    interval=45
);
