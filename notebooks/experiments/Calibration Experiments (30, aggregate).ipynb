# %%
# NUMBER OF RUNS FOR EACH OPTUNA ITERATION:
# - the number of optuna trials is computed as 1500 // n_runs
n_runs = 30

# AGGREGATION METHOD:
# - 'aggregate': aggregates the MultiSim object on the mean values and computes a single loss
# - 'average': computes the loss of each simulation in the MultiSim and the averages the n_runs losses
method = 'aggregate'

# %%
# %%capture
import sys

if 'google.colab' in sys.modules:
    # !pip install covasim==2.0.3 optuna
    # !git clone https://github.com/mazzio97/EpidemicModelLearning.git
    sys.path.append('EpidemicModelLearning/')

# %%
import optuna as op
import covasim as cv
import seaborn as sns
import matplotlib.pyplot as plt
from src import data, calibration, interventions

sns.set_context('notebook')
sns.set_style('whitegrid')

# NUMBER OF TOTAL SIMULATIONS
n_simulations = 1500

# NUMBER OF OPTUNA TRIALS
n_trials = n_simulations // n_runs
# Out:
# Covasim 2.0.3 (2021-03-11) — © 2021 by IDM

# %%
pop_size = 400e3
pop_scale = 10
cols = ['n_severe', 'n_critical', 'cum_diagnoses', 'cum_deaths']
df = data.get_regional_data(scaling_factor=4.46e6/pop_size)

default_params = dict(
    pop_type='hybrid',
    location='italy',
    start_day=df['date'].iloc[0],
    end_day=df['date'].iloc[-1],
    pop_size=pop_size / pop_scale,
    pop_scale=pop_scale,
    rescale=True,
    n_beds_hosp=pop_size * 370.4 / 100e3,
    n_beds_icu=pop_size * 14.46 / 100e3,
    quar_period=14,
    verbose=0
)

_, axes = plt.subplots(2, 2, figsize=(14, 8), sharex='all')
sns.lineplot(data=df, x='date', y='new_tests', ax=axes[0, 0]).set(title='New Tests', ylabel='')
sns.lineplot(data=df, x='date', y='cum_diagnoses', ax=axes[0, 1]).set(title='Cumulative Cases', ylabel='')
sns.lineplot(data=df, x='date', y='cum_deaths', ax=axes[1, 0]).set(title='Cumulative Deaths', ylabel='')
sns.lineplot(data=df, x='date', y='n_critical', label='critical', color='#1f77b4', linestyle='--', ax=axes[1, 1])
sns.lineplot(data=df, x='date', y='n_severe', label='severe', ax=axes[1, 1]).set(title='Active Cases', ylabel='')
plt.tight_layout()

# %%
def get_calibration_params(trial):
    return dict(
        pop_infected=trial.suggest_int('pop_infected', pop_size // 1e4, pop_size // 1e2, step=5),
        **default_params
    ), dict(
        trace_prob=trial.suggest_float('trace_prob', 0.3, 0.9, step=1e-2),
        trace_time=trial.suggest_float('trace_time', 1.0, 5.0, step=1e-1),
        work_contacts=trial.suggest_float('work_contacts', 0.4, 0.9, step=1e-2),
        school_contacts=trial.suggest_float('school_contacts', 0.2, 0.8, step=1e-2),
        yellow_casual_contacts=trial.suggest_float('yellow_casual_contacts', 0.6, 1.0, step=1e-2),
        orange_casual_contacts=trial.suggest_float('orange_casual_contacts', 0.2, 0.8, step=1e-2),
        init_imports=trial.suggest_float('init_imports', 5.0, 15.0, step=1e-1),
        yellow_imports=trial.suggest_float('yellow_imports', 4.0, 12.0, step=1e-1),
        orange_imports=trial.suggest_float('orange_imports', 2.0, 8.0, step=1e-1),
        init_beta=trial.suggest_float('init_beta', 0.01, 0.02, step=None),
        summer_beta=trial.suggest_float('summer_beta', 0.002, 0.01, step=None),
        winter_beta=trial.suggest_float('winter_beta', 0.01, 0.02, step=None),
        init_symp=trial.suggest_float('init_symp', 0.5, 2.5, log=True),
        init_sev=trial.suggest_float('init_sev', 0.5, 2.0, log=True),
        init_crit=trial.suggest_float('init_crit', 0.5, 2.0, log=True),
        init_death=trial.suggest_float('init_death', 1.5, 4.5, log=True)
    )

# %%
constraint_orderings = [
    ('yellow_casual_contacts', 'orange_casual_contacts'),
    ('init_imports', 'yellow_imports', 'orange_imports'),
    ('init_beta', 'summer_beta'),
    ('winter_beta', 'summer_beta')
]

def objective(trial):
    # define learnable parameters
    initial_params, intervention_params = get_calibration_params(trial)
    # define and run simulations, then return loss
    intervs = interventions.get_calibration_interventions(intervention_params)
    sim = cv.Sim(pars=initial_params, interventions=intervs, datafile=df)
    msim = cv.MultiSim(sim)
    msim.run(n_runs=n_runs)
    violation = calibration.compute_violation(intervention_params, constraint_orderings)
    if method == 'aggregate':
        msim.mean()
        return violation * msim.base_sim.compute_fit(keys=cols, weights={k: 1 for k in cols}).mismatch
    if method == 'average':
        mismatches = [s.compute_fit(keys=cols, weights={k: 1 for k in cols}).mismatch for s in msim.sims]
        return violation * sum(mismatches) / n_runs
    else:
        raise ValueError("method should be either 'aggregate' or 'average'")

study = op.create_study()
study.optimize(func=objective, n_trials=n_trials)
# Out:
# [I 2021-04-16 09:31:39,209] A new study created in memory with name: no-name-db9aec0a-8b47-4ce6-b70c-ae25a25a2884
# [I 2021-04-16 09:35:41,940] Trial 0 finished with value: 722.1115787849375 and parameters: {'pop_infected': 1615, 'trace_prob': 0.7, 'trace_time': 1.2, 'work_contacts': 0.5800000000000001, 'school_contacts': 0.71, 'yellow_casual_contacts': 0.97, 'orange_casual_contacts': 0.26, 'init_imports': 11.100000000000001, 'yellow_imports': 10.100000000000001, 'orange_imports': 6.800000000000001, 'init_beta': 0.018100809846680374, 'summer_beta': 0.003177926155846607, 'winter_beta': 0.010394016655974558, 'init_symp': 0.5851193384165297, 'init_sev': 1.064001996457249, 'init_crit': 1.7433983580018466, 'init_death': 4.201088385824876}. Best is trial 0 with value: 722.1115787849375.
# [I 2021-04-16 09:39:55,817] Trial 1 finished with value: 3598.261310354656 and parameters: {'pop_infected': 995, 'trace_prob': 0.59, 'trace_time': 3.4000000000000004, 'work_contacts': 0.8200000000000001, 'school_contacts': 0.22, 'yellow_casual_contacts': 0.6599999999999999, 'orange_casual_contacts': 0.46, 'init_imports': 12.8, 'yellow_imports': 6.2, 'orange_imports': 6.4, 'init_beta': 0.016598855591407634, 'summer_beta': 0.005617363933306734, 'winter_beta': 0.01626666865616548, 'init_symp': 1.4791237289549872, 'init_sev': 1.695086610560388, 'init_crit': 1.3192361887902313, 'init_death': 3.967914952569613}. Best is trial 0 with value: 722.1115787849375.
# [I 2021-04-16 09:44:03,007] Trial 2 finished with value: 1150.816794608557 and parameters: {'pop_infected': 3785, 'trace_prob': 0.31, 'trace_time': 2.9000000000000004, 'work_contacts': 0.88, 'school_contacts': 0.32, 'yellow_casual_contacts': 0.79, 'orange_casual_contacts': 0.36, 'init_imports': 13.200000000000001, 'yellow_imports': 10.4, 'orange_imports': 7.4, 'init_beta': 0.010696304307302274, 'summer_beta': 0.0020948125245072234, 'winter_beta': 0.01110041476950328, 'init_symp': 1.12100220187628, 'init_sev': 0.7634324400742701, 'init_crit': 1.9550130965430796, 'init_death': 3.6649971536543267}. Best is trial 0 with value: 722.1115787849375.
# [I 2021-04-16 09:48:16,868] Trial 3 finished with value: 819.7717807243353 and parameters: {'pop_infected': 1650, 'trace_prob': 0.78, 'trace_time': 2.9000000000000004, 'work_contacts': 0.5700000000000001, 'school_contacts': 0.2, 'yellow_casual_contacts': 1.0, 'orange_casual_contacts': 0.43000000000000005, 'init_imports': 13.5, 'yellow_imports': 11.600000000000001, 'orange_imports': 2.6, 'init_beta': 0.01126348098099208, 'summer_beta': 0.007083540935006879, 'winter_beta': 0.01641661783776179, 'init_symp': 2.306471451306431, 'init_sev': 0.668985226102069, 'init_crit': 0.6944622371869557, 'init_death': 4.10224971591443}. Best is trial 0 with value: 722.1115787849375.
# [I 2021-04-16 09:52:30,949] Trial 4 finished with value: 696.5498712486708 and parameters: {'pop_infected': 1515, 'trace_prob': 0.64, 'trace_time': 1.7000000000000002, 'work_contacts': 0.89, 'school_contacts': 0.5, 'yellow_casual_contacts': 1.0, 'orange_casual_contacts': 0.47000000000000003, 'init_imports': 12.100000000000001, 'yellow_imports': 8.5, 'orange_imports': 7.5, 'init_beta': 0.016902972897843885, 'summer_beta': 0.004917994059731864, 'winter_beta': 0.01128180620701783, 'init_symp': 0.7437892159233828, 'init_sev': 1.2148219524961328, 'init_crit': 0.5051934973814934, 'init_death': 4.494235438487819}. Best is trial 4 with value: 696.5498712486708.
# [I 2021-04-16 09:56:42,623] Trial 5 finished with value: 1002.9275944077674 and parameters: {'pop_infected': 1410, 'trace_prob': 0.77, 'trace_time': 2.8, 'work_contacts': 0.5900000000000001, 'school_contacts': 0.56, 'yellow_casual_contacts': 0.87, 'orange_casual_contacts': 0.33, 'init_imports': 14.700000000000001, 'yellow_imports': 6.800000000000001, 'orange_imports': 2.6, 'init_beta': 0.017950113650922382, 'summer_beta': 0.0022426749866091954, 'winter_beta': 0.016801867740970318, 'init_symp': 0.97711225259249, 'init_sev': 0.5930861774426922, 'init_crit': 1.8599827476976716, 'init_death': 3.540318634886327}. Best is trial 4 with value: 696.5498712486708.
# [I 2021-04-16 10:00:58,341] Trial 6 finished with value: 1746.615046833978 and parameters: {'pop_infected': 2045, 'trace_prob': 0.51, 'trace_time': 1.2, 'work_contacts': 0.8700000000000001, 'school_contacts': 0.30000000000000004, 'yellow_casual_contacts': 0.6699999999999999, 'orange_casual_contacts': 0.52, 'init_imports': 14.200000000000001, 'yellow_imports': 4.7, 'orange_imports': 7.300000000000001, 'init_beta': 0.010604555688236705, 'summer_beta': 0.007714488748130858, 'winter_beta': 0.01711249552196912, 'init_symp': 1.2645530364481103, 'init_sev': 0.9742512657186134, 'init_crit': 0.5049309891673507, 'init_death': 2.0817442768183136}. Best is trial 4 with value: 696.5498712486708.
# [I 2021-04-16 10:05:03,326] Trial 7 finished with value: 520.5175755179002 and parameters: {'pop_infected': 3620, 'trace_prob': 0.6699999999999999, 'trace_time': 3.6, 'work_contacts': 0.67, 'school_contacts': 0.27, 'yellow_casual_contacts': 0.87, 'orange_casual_contacts': 0.22, 'init_imports': 9.4, 'yellow_imports': 11.0, 'orange_imports': 5.9, 'init_beta': 0.01592456752041821, 'summer_beta': 0.006521099489335941, 'winter_beta': 0.014064026270527264, 'init_symp': 0.7556137549525327, 'init_sev': 0.7386185990506869, 'init_crit': 0.6071525926177912, 'init_death': 2.752114139159717}. Best is trial 7 with value: 520.5175755179002.
# [I 2021-04-16 10:09:11,378] Trial 8 finished with value: 534.8905856775042 and parameters: {'pop_infected': 2005, 'trace_prob': 0.77, 'trace_time': 1.1, 'work_contacts': 0.61, 'school_contacts': 0.65, 'yellow_casual_contacts': 0.6, 'orange_casual_contacts': 0.6000000000000001, 'init_imports': 10.4, 'yellow_imports': 7.2, 'orange_imports': 5.0, 'init_beta': 0.019760495823499022, 'summer_beta': 0.0049023729239620496, 'winter_beta': 0.012478409247090571, 'init_symp': 0.9036862284938714, 'init_sev': 0.7745693599853587, 'init_crit': 0.5003959996324587, 'init_death': 1.6787805116163117}. Best is trial 7 with value: 520.5175755179002.
# [I 2021-04-16 10:13:25,911] Trial 9 finished with value: 3939.838684141204 and parameters: {'pop_infected': 1325, 'trace_prob': 0.55, 'trace_time': 3.8000000000000003, 'work_contacts': 0.5900000000000001, 'school_contacts': 0.34, 'yellow_casual_contacts': 0.87, 'orange_casual_contacts': 0.5, 'init_imports': 11.7, 'yellow_imports': 7.5, 'orange_imports': 2.7, 'init_beta': 0.01928527699747988, 'summer_beta': 0.005255297451807724, 'winter_beta': 0.019115459506835117, 'init_symp': 1.229474503245563, 'init_sev': 1.5201235847926158, 'init_crit': 1.6787770487767628, 'init_death': 1.5520138847819627}. Best is trial 7 with value: 520.5175755179002.
# [I 2021-04-16 10:17:34,405] Trial 10 finished with value: 852.8823807540978 and parameters: {'pop_infected': 3945, 'trace_prob': 0.41, 'trace_time': 5.0, 'work_contacts': 0.42000000000000004, 'school_contacts': 0.46, 'yellow_casual_contacts': 0.78, 'orange_casual_contacts': 0.77, 'init_imports': 7.2, 'yellow_imports': 12.0, 'orange_imports': 4.9, 'init_beta': 0.013882657101806448, 'summer_beta': 0.009728987550884104, 'winter_beta': 0.013567142839085404, 'init_symp': 0.5053345937394589, 'init_sev': 0.5059212404596756, 'init_crit': 0.7750824943370869, 'init_death': 2.461158097539743}. Best is trial 7 with value: 520.5175755179002.
# [I 2021-04-16 10:21:45,148] Trial 11 finished with value: 350.5313277241041 and parameters: {'pop_infected': 2830, 'trace_prob': 0.8899999999999999, 'trace_time': 4.4, 'work_contacts': 0.7, 'school_contacts': 0.8, 'yellow_casual_contacts': 0.8899999999999999, 'orange_casual_contacts': 0.65, 'init_imports': 8.2, 'yellow_imports': 8.8, 'orange_imports': 5.0, 'init_beta': 0.013812612094878681, 'summer_beta': 0.004079119254214943, 'winter_beta': 0.013228973164213603, 'init_symp': 0.7755825915794732, 'init_sev': 0.7891780036420117, 'init_crit': 0.6394016394312205, 'init_death': 2.781782079422207}. Best is trial 11 with value: 350.5313277241041.
# [I 2021-04-16 10:25:54,858] Trial 12 finished with value: 338.84823979050486 and parameters: {'pop_infected': 2860, 'trace_prob': 0.8999999999999999, 'trace_time': 4.9, 'work_contacts': 0.75, 'school_contacts': 0.43000000000000005, 'yellow_casual_contacts': 0.8899999999999999, 'orange_casual_contacts': 0.71, 'init_imports': 8.1, 'yellow_imports': 9.100000000000001, 'orange_imports': 5.2, 'init_beta': 0.013699404289448148, 'summer_beta': 0.00362694731488226, 'winter_beta': 0.013778005395062564, 'init_symp': 0.6807628011704471, 'init_sev': 0.8845873754928242, 'init_crit': 0.6831006660263105, 'init_death': 2.9942029131695116}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 10:30:07,596] Trial 13 finished with value: 820.3817915649918 and parameters: {'pop_infected': 2960, 'trace_prob': 0.8999999999999999, 'trace_time': 4.9, 'work_contacts': 0.73, 'school_contacts': 0.8, 'yellow_casual_contacts': 0.9199999999999999, 'orange_casual_contacts': 0.76, 'init_imports': 5.1, 'yellow_imports': 9.0, 'orange_imports': 4.1, 'init_beta': 0.0132944805873563, 'summer_beta': 0.004085920998779297, 'winter_beta': 0.014726296130150281, 'init_symp': 0.6414319727427591, 'init_sev': 0.9436349931794702, 'init_crit': 0.9509261196625823, 'init_death': 3.0732653685711018}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 10:34:15,452] Trial 14 finished with value: 551.2135349178134 and parameters: {'pop_infected': 2915, 'trace_prob': 0.8999999999999999, 'trace_time': 4.300000000000001, 'work_contacts': 0.75, 'school_contacts': 0.41000000000000003, 'yellow_casual_contacts': 0.94, 'orange_casual_contacts': 0.67, 'init_imports': 8.3, 'yellow_imports': 9.600000000000001, 'orange_imports': 4.0, 'init_beta': 0.012671613338228397, 'summer_beta': 0.003563239121130768, 'winter_beta': 0.013279651980869115, 'init_symp': 0.5135485263561833, 'init_sev': 1.3206856043793322, 'init_crit': 0.8487981238804536, 'init_death': 2.2666202239553073}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 10:38:25,698] Trial 15 finished with value: 456.51852728952355 and parameters: {'pop_infected': 250, 'trace_prob': 0.8500000000000001, 'trace_time': 4.5, 'work_contacts': 0.78, 'school_contacts': 0.64, 'yellow_casual_contacts': 0.83, 'orange_casual_contacts': 0.6799999999999999, 'init_imports': 6.2, 'yellow_imports': 8.5, 'orange_imports': 5.5, 'init_beta': 0.014676569413541927, 'summer_beta': 0.0029786967632681885, 'winter_beta': 0.01230049189958062, 'init_symp': 0.774437541907847, 'init_sev': 0.9240762640541705, 'init_crit': 0.6381212492017375, 'init_death': 2.991040181497554}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 10:42:35,027] Trial 16 finished with value: 490.52440986618444 and parameters: {'pop_infected': 2825, 'trace_prob': 0.8700000000000001, 'trace_time': 4.6, 'work_contacts': 0.68, 'school_contacts': 0.4, 'yellow_casual_contacts': 0.75, 'orange_casual_contacts': 0.62, 'init_imports': 8.8, 'yellow_imports': 5.6, 'orange_imports': 3.9000000000000004, 'init_beta': 0.01259552728222186, 'summer_beta': 0.004011044231453202, 'winter_beta': 0.015247034772320266, 'init_symp': 1.6200409091788632, 'init_sev': 0.5186706638299952, 'init_crit': 1.136144769872956, 'init_death': 3.2486969693149446}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 10:46:39,411] Trial 17 finished with value: 401.65035884173307 and parameters: {'pop_infected': 3335, 'trace_prob': 0.8200000000000001, 'trace_time': 4.1, 'work_contacts': 0.5, 'school_contacts': 0.54, 'yellow_casual_contacts': 0.9199999999999999, 'orange_casual_contacts': 0.71, 'init_imports': 7.7, 'yellow_imports': 9.4, 'orange_imports': 4.800000000000001, 'init_beta': 0.014905990268251063, 'summer_beta': 0.0020453507360546092, 'winter_beta': 0.012338955726375823, 'init_symp': 0.6203079434587044, 'init_sev': 0.6347320952616085, 'init_crit': 0.6024593707670308, 'init_death': 1.9296223286448808}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 10:50:57,737] Trial 18 finished with value: 1195.7671583636575 and parameters: {'pop_infected': 2335, 'trace_prob': 0.72, 'trace_time': 2.2, 'work_contacts': 0.81, 'school_contacts': 0.8, 'yellow_casual_contacts': 0.83, 'orange_casual_contacts': 0.8, 'init_imports': 6.3, 'yellow_imports': 7.800000000000001, 'orange_imports': 5.9, 'init_beta': 0.011511173501607179, 'summer_beta': 0.004351812624532029, 'winter_beta': 0.018312152054330705, 'init_symp': 0.9464284560381219, 'init_sev': 0.8507983379948278, 'init_crit': 0.7541521250519623, 'init_death': 2.578037646018119}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 10:55:14,527] Trial 19 finished with value: 1365.8561289807744 and parameters: {'pop_infected': 2540, 'trace_prob': 0.8999999999999999, 'trace_time': 5.0, 'work_contacts': 0.71, 'school_contacts': 0.39, 'yellow_casual_contacts': 0.8899999999999999, 'orange_casual_contacts': 0.5800000000000001, 'init_imports': 9.9, 'yellow_imports': 10.8, 'orange_imports': 3.5, 'init_beta': 0.013931281824858, 'summer_beta': 0.008547290138025139, 'winter_beta': 0.015165276628678316, 'init_symp': 0.8315641179761848, 'init_sev': 1.1995381787456871, 'init_crit': 0.9051172386502065, 'init_death': 2.8788422985023527}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 10:59:24,593] Trial 20 finished with value: 864.4845358619123 and parameters: {'pop_infected': 3425, 'trace_prob': 0.44, 'trace_time': 4.0, 'work_contacts': 0.64, 'school_contacts': 0.62, 'yellow_casual_contacts': 0.72, 'orange_casual_contacts': 0.73, 'init_imports': 5.1, 'yellow_imports': 8.100000000000001, 'orange_imports': 5.4, 'init_beta': 0.012194715268938835, 'summer_beta': 0.006191816436821263, 'winter_beta': 0.014443847453447466, 'init_symp': 0.6950241471352897, 'init_sev': 1.103587224985543, 'init_crit': 0.5787286717075009, 'init_death': 2.3745381815766797}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 11:03:31,202] Trial 21 finished with value: 411.29478622651624 and parameters: {'pop_infected': 3355, 'trace_prob': 0.8300000000000001, 'trace_time': 4.2, 'work_contacts': 0.51, 'school_contacts': 0.54, 'yellow_casual_contacts': 0.9299999999999999, 'orange_casual_contacts': 0.71, 'init_imports': 7.9, 'yellow_imports': 9.4, 'orange_imports': 4.6, 'init_beta': 0.015072652686699758, 'summer_beta': 0.0024952106334816876, 'winter_beta': 0.012324961949730396, 'init_symp': 0.5873125900953264, 'init_sev': 0.6103407294030818, 'init_crit': 0.5695168184729654, 'init_death': 1.9418367667353076}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 11:07:37,973] Trial 22 finished with value: 440.44496762139084 and parameters: {'pop_infected': 3185, 'trace_prob': 0.8200000000000001, 'trace_time': 4.7, 'work_contacts': 0.41000000000000003, 'school_contacts': 0.73, 'yellow_casual_contacts': 0.96, 'orange_casual_contacts': 0.65, 'init_imports': 7.1, 'yellow_imports': 9.100000000000001, 'orange_imports': 4.5, 'init_beta': 0.014958737590090115, 'summer_beta': 0.002996871637965446, 'winter_beta': 0.012961934270666341, 'init_symp': 0.5905272915294291, 'init_sev': 0.6329825353648066, 'init_crit': 0.6838845302958038, 'init_death': 1.8302987864585067}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 11:11:44,047] Trial 23 finished with value: 421.63453879293985 and parameters: {'pop_infected': 2550, 'trace_prob': 0.8200000000000001, 'trace_time': 4.1, 'work_contacts': 0.48000000000000004, 'school_contacts': 0.45, 'yellow_casual_contacts': 0.8999999999999999, 'orange_casual_contacts': 0.8, 'init_imports': 7.5, 'yellow_imports': 9.7, 'orange_imports': 3.3, 'init_beta': 0.013831114958850442, 'summer_beta': 0.003613244999569498, 'winter_beta': 0.011426075507412899, 'init_symp': 0.6603176616044645, 'init_sev': 0.8303425989572515, 'init_crit': 0.5521290338901345, 'init_death': 2.1953829549600266}. Best is trial 12 with value: 338.84823979050486.
# [I 2021-04-16 11:15:49,338] Trial 24 finished with value: 309.49752657077073 and parameters: {'pop_infected': 3210, 'trace_prob': 0.8999999999999999, 'trace_time': 3.6, 'work_contacts': 0.53, 'school_contacts': 0.56, 'yellow_casual_contacts': 0.83, 'orange_casual_contacts': 0.5700000000000001, 'init_imports': 8.7, 'yellow_imports': 8.600000000000001, 'orange_imports': 5.4, 'init_beta': 0.015901127548556843, 'summer_beta': 0.0021099358035430492, 'winter_beta': 0.013778448636806976, 'init_symp': 0.5348179816328047, 'init_sev': 0.6932722699529588, 'init_crit': 1.1036676266329266, 'init_death': 3.3232847388561013}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:20:02,050] Trial 25 finished with value: 618.7878918130979 and parameters: {'pop_infected': 2680, 'trace_prob': 0.8999999999999999, 'trace_time': 3.3000000000000003, 'work_contacts': 0.54, 'school_contacts': 0.74, 'yellow_casual_contacts': 0.83, 'orange_casual_contacts': 0.55, 'init_imports': 9.3, 'yellow_imports': 8.5, 'orange_imports': 6.3, 'init_beta': 0.016169130194468407, 'summer_beta': 0.0026501431179589197, 'winter_beta': 0.015588952966852494, 'init_symp': 0.8542411483881007, 'init_sev': 0.7278737431827836, 'init_crit': 1.1434127591465844, 'init_death': 3.350523643869508}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:24:06,607] Trial 26 finished with value: 322.1193722422282 and parameters: {'pop_infected': 3030, 'trace_prob': 0.74, 'trace_time': 2.5, 'work_contacts': 0.64, 'school_contacts': 0.5800000000000001, 'yellow_casual_contacts': 0.83, 'orange_casual_contacts': 0.64, 'init_imports': 6.2, 'yellow_imports': 7.0, 'orange_imports': 5.4, 'init_beta': 0.01568265516313118, 'summer_beta': 0.0034537863731238312, 'winter_beta': 0.013828436791171935, 'init_symp': 0.5031933621809727, 'init_sev': 0.5552241457660633, 'init_crit': 1.1184157973652622, 'init_death': 2.692196812272392}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:28:10,843] Trial 27 finished with value: 326.3913144006901 and parameters: {'pop_infected': 3135, 'trace_prob': 0.73, 'trace_time': 2.4000000000000004, 'work_contacts': 0.45, 'school_contacts': 0.5700000000000001, 'yellow_casual_contacts': 0.8099999999999999, 'orange_casual_contacts': 0.56, 'init_imports': 6.0, 'yellow_imports': 6.6, 'orange_imports': 5.5, 'init_beta': 0.01775331788754016, 'summer_beta': 0.004600634649189277, 'winter_beta': 0.014024947181904071, 'init_symp': 0.5344943943260714, 'init_sev': 0.5289616575577155, 'init_crit': 1.4510368285604234, 'init_death': 3.728823661564463}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:32:14,781] Trial 28 finished with value: 325.30358981732655 and parameters: {'pop_infected': 3630, 'trace_prob': 0.72, 'trace_time': 2.4000000000000004, 'work_contacts': 0.45, 'school_contacts': 0.5900000000000001, 'yellow_casual_contacts': 0.75, 'orange_casual_contacts': 0.56, 'init_imports': 5.9, 'yellow_imports': 5.4, 'orange_imports': 5.800000000000001, 'init_beta': 0.01773979985229529, 'summer_beta': 0.004710489950434924, 'winter_beta': 0.0141259424725938, 'init_symp': 0.503524336329393, 'init_sev': 0.5427652078676841, 'init_crit': 1.4298578232502217, 'init_death': 3.733014453855394}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:36:14,576] Trial 29 finished with value: 608.0915717280012 and parameters: {'pop_infected': 3595, 'trace_prob': 0.6699999999999999, 'trace_time': 2.4000000000000004, 'work_contacts': 0.54, 'school_contacts': 0.5900000000000001, 'yellow_casual_contacts': 0.74, 'orange_casual_contacts': 0.4, 'init_imports': 5.6, 'yellow_imports': 4.7, 'orange_imports': 8.0, 'init_beta': 0.01715192727150833, 'summer_beta': 0.00561101984203049, 'winter_beta': 0.010473930898208075, 'init_symp': 0.5489328649489114, 'init_sev': 0.5565069493214252, 'init_crit': 1.0675089694281408, 'init_death': 3.382796418025564}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:40:18,460] Trial 30 finished with value: 440.217650156123 and parameters: {'pop_infected': 3680, 'trace_prob': 0.62, 'trace_time': 1.6, 'work_contacts': 0.46, 'school_contacts': 0.5, 'yellow_casual_contacts': 0.71, 'orange_casual_contacts': 0.52, 'init_imports': 6.7, 'yellow_imports': 5.4, 'orange_imports': 6.800000000000001, 'init_beta': 0.01877874362763116, 'summer_beta': 0.0031732588575765445, 'winter_beta': 0.015896344831935968, 'init_symp': 0.5114870554177836, 'init_sev': 0.568033756839065, 'init_crit': 1.3188324194143772, 'init_death': 4.488654932976846}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:44:24,129] Trial 31 finished with value: 409.69150116619056 and parameters: {'pop_infected': 3935, 'trace_prob': 0.72, 'trace_time': 2.3, 'work_contacts': 0.45, 'school_contacts': 0.69, 'yellow_casual_contacts': 0.8099999999999999, 'orange_casual_contacts': 0.5800000000000001, 'init_imports': 5.8, 'yellow_imports': 6.5, 'orange_imports': 5.7, 'init_beta': 0.017897003537713747, 'summer_beta': 0.004708593830476798, 'winter_beta': 0.014680250819200477, 'init_symp': 0.5608843119216036, 'init_sev': 0.5024951775692871, 'init_crit': 1.543661118927383, 'init_death': 3.9383296762220823}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:48:26,155] Trial 32 finished with value: 328.99975599663827 and parameters: {'pop_infected': 3190, 'trace_prob': 0.73, 'trace_time': 2.6, 'work_contacts': 0.4, 'school_contacts': 0.5800000000000001, 'yellow_casual_contacts': 0.77, 'orange_casual_contacts': 0.55, 'init_imports': 5.5, 'yellow_imports': 6.300000000000001, 'orange_imports': 6.4, 'init_beta': 0.017296951030108705, 'summer_beta': 0.004419595273517174, 'winter_beta': 0.014098465048653093, 'init_symp': 0.5064845784628446, 'init_sev': 0.5487344802623242, 'init_crit': 1.3628111730093504, 'init_death': 3.7111420306866667}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:52:33,789] Trial 33 finished with value: 383.6387227104412 and parameters: {'pop_infected': 3150, 'trace_prob': 0.6799999999999999, 'trace_time': 3.2, 'work_contacts': 0.44, 'school_contacts': 0.67, 'yellow_casual_contacts': 0.8099999999999999, 'orange_casual_contacts': 0.6100000000000001, 'init_imports': 6.3, 'yellow_imports': 5.6, 'orange_imports': 6.1000000000000005, 'init_beta': 0.015726942067098668, 'summer_beta': 0.005748088260199141, 'winter_beta': 0.014189920659261801, 'init_symp': 0.5366415546738467, 'init_sev': 0.5031111345287645, 'init_crit': 1.4443583387270327, 'init_death': 3.8304810854876754}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 11:56:44,349] Trial 34 finished with value: 1073.4101402625183 and parameters: {'pop_infected': 3870, 'trace_prob': 0.75, 'trace_time': 2.0, 'work_contacts': 0.52, 'school_contacts': 0.6100000000000001, 'yellow_casual_contacts': 0.85, 'orange_casual_contacts': 0.46, 'init_imports': 6.8, 'yellow_imports': 7.2, 'orange_imports': 6.7, 'init_beta': 0.01867535236125761, 'summer_beta': 0.005307059742757933, 'winter_beta': 0.012849733051044396, 'init_symp': 2.3835362917818905, 'init_sev': 0.6805211118307714, 'init_crit': 1.2328019132192827, 'init_death': 4.245215678319295}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:00:48,443] Trial 35 finished with value: 665.1602977728944 and parameters: {'pop_infected': 2345, 'trace_prob': 0.5800000000000001, 'trace_time': 2.6, 'work_contacts': 0.48000000000000004, 'school_contacts': 0.54, 'yellow_casual_contacts': 0.77, 'orange_casual_contacts': 0.55, 'init_imports': 5.2, 'yellow_imports': 5.1, 'orange_imports': 5.6, 'init_beta': 0.016388347830025716, 'summer_beta': 0.0038163457972465132, 'winter_beta': 0.011880569199309663, 'init_symp': 2.067082048786115, 'init_sev': 0.6810501339379144, 'init_crit': 1.5694666802119857, 'init_death': 3.4797825632390675}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:04:56,388] Trial 36 finished with value: 365.41219962890773 and parameters: {'pop_infected': 3495, 'trace_prob': 0.78, 'trace_time': 1.9, 'work_contacts': 0.63, 'school_contacts': 0.49, 'yellow_casual_contacts': 0.69, 'orange_casual_contacts': 0.63, 'init_imports': 10.600000000000001, 'yellow_imports': 6.0, 'orange_imports': 5.300000000000001, 'init_beta': 0.01756825947316759, 'summer_beta': 0.004633371115993866, 'winter_beta': 0.013732540677334216, 'init_symp': 0.5926790740603857, 'init_sev': 0.5595416565076846, 'init_crit': 1.016688457670856, 'init_death': 4.238352514030004}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:08:58,987] Trial 37 finished with value: 318.8744638514167 and parameters: {'pop_infected': 3110, 'trace_prob': 0.63, 'trace_time': 3.1, 'work_contacts': 0.54, 'school_contacts': 0.5700000000000001, 'yellow_casual_contacts': 0.8, 'orange_casual_contacts': 0.49, 'init_imports': 5.9, 'yellow_imports': 6.800000000000001, 'orange_imports': 4.4, 'init_beta': 0.016717345362363228, 'summer_beta': 0.002657191793878405, 'winter_beta': 0.014781754458316079, 'init_symp': 0.5005548298039624, 'init_sev': 0.5290309749301176, 'init_crit': 1.2692107185170807, 'init_death': 3.2619250957294987}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:13:03,665] Trial 38 finished with value: 339.5195671133011 and parameters: {'pop_infected': 3750, 'trace_prob': 0.63, 'trace_time': 3.0, 'work_contacts': 0.56, 'school_contacts': 0.6100000000000001, 'yellow_casual_contacts': 0.79, 'orange_casual_contacts': 0.4, 'init_imports': 6.8, 'yellow_imports': 4.2, 'orange_imports': 4.4, 'init_beta': 0.01565863068351787, 'summer_beta': 0.0026074949072516867, 'winter_beta': 0.01622250407639349, 'init_symp': 0.508059015806877, 'init_sev': 0.5957169923184465, 'init_crit': 1.1997971170642954, 'init_death': 3.2575371966001287}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:17:13,427] Trial 39 finished with value: 1955.0000813132551 and parameters: {'pop_infected': 2055, 'trace_prob': 0.53, 'trace_time': 3.1, 'work_contacts': 0.61, 'school_contacts': 0.52, 'yellow_casual_contacts': 0.75, 'orange_casual_contacts': 0.48000000000000004, 'init_imports': 8.7, 'yellow_imports': 6.0, 'orange_imports': 4.300000000000001, 'init_beta': 0.01647284641929739, 'summer_beta': 0.0020461434798578226, 'winter_beta': 0.017096310552259103, 'init_symp': 0.7057673288734917, 'init_sev': 1.9082936815588332, 'init_crit': 1.0781227003233655, 'init_death': 2.6103250232980644}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:21:23,920] Trial 40 finished with value: 914.4065291355199 and parameters: {'pop_infected': 555, 'trace_prob': 0.48, 'trace_time': 3.5, 'work_contacts': 0.56, 'school_contacts': 0.48000000000000004, 'yellow_casual_contacts': 0.85, 'orange_casual_contacts': 0.34, 'init_imports': 11.4, 'yellow_imports': 6.9, 'orange_imports': 7.2, 'init_beta': 0.016930245077464788, 'summer_beta': 0.0033318692915194374, 'winter_beta': 0.015527984517813894, 'init_symp': 1.0673248514394398, 'init_sev': 0.6658054515756388, 'init_crit': 1.275923590888157, 'init_death': 3.1836814633138246}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:25:26,748] Trial 41 finished with value: 347.3821199620815 and parameters: {'pop_infected': 3145, 'trace_prob': 0.5800000000000001, 'trace_time': 2.7, 'work_contacts': 0.48000000000000004, 'school_contacts': 0.5700000000000001, 'yellow_casual_contacts': 0.8, 'orange_casual_contacts': 0.43000000000000005, 'init_imports': 5.9, 'yellow_imports': 6.800000000000001, 'orange_imports': 5.800000000000001, 'init_beta': 0.0184535934069547, 'summer_beta': 0.002799513590559756, 'winter_beta': 0.014702889163821963, 'init_symp': 0.5549896525382306, 'init_sev': 0.5288909314810509, 'init_crit': 1.4487625081120412, 'init_death': 3.690121710743535}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:29:31,463] Trial 42 finished with value: 655.9407911005982 and parameters: {'pop_infected': 3105, 'trace_prob': 0.69, 'trace_time': 2.9000000000000004, 'work_contacts': 0.43000000000000005, 'school_contacts': 0.65, 'yellow_casual_contacts': 0.85, 'orange_casual_contacts': 0.51, 'init_imports': 5.0, 'yellow_imports': 7.9, 'orange_imports': 5.2, 'init_beta': 0.017644386400015227, 'summer_beta': 0.005173479006044521, 'winter_beta': 0.013548374601444067, 'init_symp': 0.6202761786797943, 'init_sev': 0.59372030990762, 'init_crit': 1.8534442188257998, 'init_death': 3.504450775713166}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:33:39,237] Trial 43 finished with value: 405.45520442639605 and parameters: {'pop_infected': 4000, 'trace_prob': 0.6599999999999999, 'trace_time': 3.8000000000000003, 'work_contacts': 0.54, 'school_contacts': 0.56, 'yellow_casual_contacts': 0.82, 'orange_casual_contacts': 0.5800000000000001, 'init_imports': 12.600000000000001, 'yellow_imports': 7.2, 'orange_imports': 6.1000000000000005, 'init_beta': 0.016906146194937265, 'summer_beta': 0.0022833536236045657, 'winter_beta': 0.014235001913421032, 'init_symp': 0.5048157354735865, 'init_sev': 0.5303030436574044, 'init_crit': 1.3923098535118448, 'init_death': 4.032314781067229}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:37:42,878] Trial 44 finished with value: 366.6862472236377 and parameters: {'pop_infected': 3515, 'trace_prob': 0.79, 'trace_time': 1.4, 'work_contacts': 0.5900000000000001, 'school_contacts': 0.52, 'yellow_casual_contacts': 0.62, 'orange_casual_contacts': 0.55, 'init_imports': 6.4, 'yellow_imports': 6.5, 'orange_imports': 4.9, 'init_beta': 0.0155532258160155, 'summer_beta': 0.003405016810807265, 'winter_beta': 0.01510585613886404, 'init_symp': 0.5478077738441496, 'init_sev': 0.5785612488412484, 'init_crit': 1.6605156174330593, 'init_death': 3.6018370825392716}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:41:48,081] Trial 45 finished with value: 500.3703108857412 and parameters: {'pop_infected': 3320, 'trace_prob': 0.75, 'trace_time': 2.4000000000000004, 'work_contacts': 0.46, 'school_contacts': 0.6000000000000001, 'yellow_casual_contacts': 0.78, 'orange_casual_contacts': 0.48000000000000004, 'init_imports': 5.7, 'yellow_imports': 8.2, 'orange_imports': 4.7, 'init_beta': 0.019972129158776518, 'summer_beta': 0.00635205803927256, 'winter_beta': 0.012969627168858315, 'init_symp': 0.6170804801772783, 'init_sev': 0.5011298743133711, 'init_crit': 1.1813170860464588, 'init_death': 3.1047589230899937}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:45:54,783] Trial 46 finished with value: 560.8560387774368 and parameters: {'pop_infected': 3005, 'trace_prob': 0.61, 'trace_time': 2.1, 'work_contacts': 0.5, 'school_contacts': 0.63, 'yellow_casual_contacts': 0.73, 'orange_casual_contacts': 0.53, 'init_imports': 7.300000000000001, 'yellow_imports': 7.5, 'orange_imports': 5.2, 'init_beta': 0.01937040827306564, 'summer_beta': 0.0070916354554780995, 'winter_beta': 0.013911136214069149, 'init_symp': 0.5010713756560367, 'init_sev': 0.7200721096088408, 'init_crit': 1.5298258764492285, 'init_death': 3.846211899466459}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:50:05,932] Trial 47 finished with value: 1497.7868933181721 and parameters: {'pop_infected': 2650, 'trace_prob': 0.71, 'trace_time': 2.5, 'work_contacts': 0.67, 'school_contacts': 0.6799999999999999, 'yellow_casual_contacts': 0.76, 'orange_casual_contacts': 0.5900000000000001, 'init_imports': 6.1, 'yellow_imports': 4.1, 'orange_imports': 6.5, 'init_beta': 0.01828073248764663, 'summer_beta': 0.004349677024216973, 'winter_beta': 0.01329066358268704, 'init_symp': 1.6549794935747817, 'init_sev': 0.6382989786005583, 'init_crit': 1.2696356493519594, 'init_death': 2.8340115843321665}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:54:10,876] Trial 48 finished with value: 422.1139078004612 and parameters: {'pop_infected': 2400, 'trace_prob': 0.65, 'trace_time': 2.8, 'work_contacts': 0.5700000000000001, 'school_contacts': 0.5800000000000001, 'yellow_casual_contacts': 0.86, 'orange_casual_contacts': 0.44, 'init_imports': 5.4, 'yellow_imports': 7.5, 'orange_imports': 3.5, 'init_beta': 0.01659845099189688, 'summer_beta': 0.0049960230386723575, 'winter_beta': 0.01460874565948262, 'init_symp': 0.5386847030314139, 'init_sev': 0.5347166213117877, 'init_crit': 0.9884252224430324, 'init_death': 2.6874894431433334}. Best is trial 24 with value: 309.49752657077073.
# [I 2021-04-16 12:58:19,869] Trial 49 finished with value: 592.2419009293964 and parameters: {'pop_infected': 3740, 'trace_prob': 0.75, 'trace_time': 3.6, 'work_contacts': 0.4, 'school_contacts': 0.52, 'yellow_casual_contacts': 0.79, 'orange_casual_contacts': 0.66, 'init_imports': 6.8, 'yellow_imports': 4.9, 'orange_imports': 6.0, 'init_beta': 0.015995315862825023, 'summer_beta': 0.0038714745048967006, 'winter_beta': 0.016434763523760845, 'init_symp': 0.7270030945376266, 'init_sev': 0.6004854384094919, 'init_crit': 1.072464606437497, 'init_death': 4.471892965987554}. Best is trial 24 with value: 309.49752657077073.

# %%
objectives = study.trials_dataframe()['value']
sns.lineplot(x=objectives.index, y=objectives)
plt.show()

# %%
calibration.inspect_study(study, top=10)[1]
# Out:
#                         count          min  ...         std         best
# objective                  10   309.497527  ...   13.035523   309.497527
# pop_infected               10  2830.000000  ...  294.983992  3210.000000
# trace_prob                 10     0.580000  ...    0.117308     0.900000
# trace_time                 10     2.400000  ...    0.875849     3.600000
# work_contacts              10     0.400000  ...    0.114795     0.530000
# school_contacts            10     0.430000  ...    0.089592     0.560000
# yellow_casual_contacts     10     0.750000  ...    0.045995     0.830000
# orange_casual_contacts     10     0.400000  ...    0.096862     0.570000
# init_imports               10     5.500000  ...    1.169805     8.700000
# yellow_imports             10     4.200000  ...    1.539264     8.600000
# orange_imports             10     4.400000  ...    0.621915     5.400000
# init_beta                  10     0.013699  ...    0.001629     0.015901
# summer_beta                10     0.002110  ...    0.000931     0.002110
# winter_beta                10     0.013229  ...    0.000825     0.013778
# init_symp                  10     0.500555  ...    0.093024     0.534818
# init_sev                   10     0.528891  ...    0.126793     0.693272
# init_crit                  10     0.639402  ...    0.297730     1.103668
# init_death                 10     2.692197  ...    0.397894     3.323285
#
# [18 rows x 7 columns]

# %%
initial_params = {'pop_infected': study.best_params['pop_infected'], **default_params}
intervs = interventions.get_calibration_interventions(study.best_params)
sim = cv.Sim(pars=initial_params, interventions=intervs, datafile=df)
msim = cv.MultiSim(sim)
msim.run(n_runs=30)
msim.mean()
msim.plot(
    list(cols) + ['n_infectious', 'n_susceptible'],
    fig_args={'figsize': (18, 8)},
    scatter_args={'s': 5},
    plot_args={'lw': 2},
    interval=45
);
